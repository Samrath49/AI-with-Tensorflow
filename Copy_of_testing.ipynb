# %% [markdown]
# <a href="https://colab.research.google.com/github/Samrath49/AI-with-Tensorflow/blob/master/Copy_of_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **day 2**

# %% [markdown]
# # Course - The Beginning

# %%
import tensorflow as tf
from tensorflow import keras 
from keras import layers
import numpy as np

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 14.8210
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 11.8997
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5964
# Epoch 4/500
# 1/1 [==============================] - 0s 993us/step - loss: 7.7795
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3453
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2123
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3164
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6072
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0448
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5981
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2425
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9587
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.981674]]
